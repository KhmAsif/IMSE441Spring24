# %% [markdown]
# <a href="https://colab.research.google.com/github/KhmAsif/IMSE441Spring24/blob/main/Lab_3_Partial_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question 1**
#
# The following table shows the typical depth (rounded to the nearest foot) for nonfueled wells in geological formations in Baltimore County (The Journal of Data Science, 2009, Vol. 7, pp. 111–127).
#
#
# If X denotes the depth of nonfueled wells
#
# a) Calculate the probability mass function of X
#
# b) Determine the cumulative distribution function for X
#
# c) Calculate the mean and variance for X
#
# Assume that four wells are selected randomly (without replacement) for inspection
#
# d) What is the probability that exactly two are selected from Loch Raven Schist?
#
# e) What is the probability that one or more is selected from the Loch Raven Schist?
#
# f) What is the expected number selected from the Loch Raven Schist?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import hypergeom, poisson,expon

# %%
#Q4-A
A = hypergeom.pmf(k=2,M=500,n=50,N=20)
print('Q4-A = ', A)
#B
B = hypergeom.cdf(k=1,M=500,n=50,N=20)
print('Q4-B = ', B)
#C - is k 2 or 3
C = hypergeom.sf(k=2,M=500,n=50,N=20)
print('Q4-C = ', C)
#D
mean, var = hypergeom.stats(M=500,n=50,N=20)
print('Q4-D Mean = ', mean, 'Q4-D Variance = ', var)
# Out:
# Q4-A =  0.29103998621932
# Q4-B =  0.3865061034605668
# Q4-C =  0.32245391032011333
# Q4-D Mean =  2.0 Q4-D Variance =  1.7314629258517034

# %%
#Question 5

#A
A_Q5 = poisson.pmf(k=0, mu=1.5)
print('Q5-A = ', A_Q5)
#B
B_Q5 = poisson.pmf(k=0, mu=15)
print('Q5-B = ', B_Q5)
#C
print('Q5-C = No. Lack of memory property')

#D
D_Q5 = expon.ppf(1-0.001, scale=1/1.5)
print('QD-D = ', D_Q5)
# Out:
# Q5-A =  0.22313016014842982
# Q5-B =  3.059023205018258e-07
# Q5-C = No. Lack of memory property
# QD-D =  4.60517018598809

# %%
#E
x = np.arange(0, 40)
mu=1.5*10
pmf = poisson.pmf(x, mu)


plt.vlines(x,0, pmf, colors='b', lw=5, alpha=0.5)

plt.xlabel('Time (minutes)')
plt.ylabel('Probability')
plt.title('Poisson Distribution (mu = 1.5 *10)')

plt.show()
