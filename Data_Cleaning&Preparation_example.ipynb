# %% [markdown]
# <a href="https://colab.research.google.com/github/KhmAsif/IMSE441Spring24/blob/main/Data_Cleaning%26Preparation_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# # Data upload

# %%
data=pd.read_csv('/content/drive/MyDrive/IMSE_441/dataset_olympics.csv')

# %%
data
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %% [markdown]
# # Data type check

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      70000 non-null  int64
#  1   Name    70000 non-null  object
#  2   Sex     70000 non-null  object
#  3   Age     67268 non-null  float64
#  4   Height  53746 non-null  float64
#  5   Weight  52899 non-null  float64
#  6   Team    70000 non-null  object
#  7   NOC     70000 non-null  object
#  8   Games   70000 non-null  object
#  9   Year    70000 non-null  int64
#  10  Season  70000 non-null  object
#  11  City    70000 non-null  object
#  12  Sport   70000 non-null  object
#  13  Event   70000 non-null  object
#  14  Medal   9690 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 8.0+ MB

# %% [markdown]
# # Data type modification

# %%
data['Year']=data['Year'].astype(object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      70000 non-null  int64
#  1   Name    70000 non-null  object
#  2   Sex     70000 non-null  object
#  3   Age     67268 non-null  float64
#  4   Height  53746 non-null  float64
#  5   Weight  52899 non-null  float64
#  6   Team    70000 non-null  object
#  7   NOC     70000 non-null  object
#  8   Games   70000 non-null  object
#  9   Year    70000 non-null  object
#  10  Season  70000 non-null  object
#  11  City    70000 non-null  object
#  12  Sport   70000 non-null  object
#  13  Event   70000 non-null  object
#  14  Medal   9690 non-null   object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 8.0+ MB

# %%
data['Year']=data['Year'].astype(float)

# %% [markdown]
# # **Data selection**

# %%
data=data[data['Year']>2000]

# %%
data
# Out:
#           ID                      Name Sex   Age  Height  Weight  \
# 1          2                  A Lamusi   M  23.0   170.0    60.0
# 28         9          Antti Sami Aalto   M  26.0   186.0    96.0
# 40        16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 72        20        Kjetil Andr Aamodt   M  30.0   176.0    85.0
# 73        20        Kjetil Andr Aamodt   M  30.0   176.0    85.0
# ...      ...                       ...  ..   ...     ...     ...
# 69988  35653     Casey J. FitzRandolph   M  27.0   180.0    79.0
# 69989  35653     Casey J. FitzRandolph   M  27.0   180.0    79.0
# 69990  35653     Casey J. FitzRandolph   M  31.0   180.0    79.0
# 69991  35653     Casey J. FitzRandolph   M  31.0   180.0    79.0
# 69993  35655         Riley Fitzsimmons   M  20.0   192.0    93.0
#
#                 Team  NOC        Games  Year  Season            City  \
# 1              China  CHN  2012 Summer  2012  Summer          London
# ...

# %%
data=data.iloc[0:100,0:10]

# %%
data
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ..  ..                                 ...  ..   ...     ...     ...
# 95  32                Olav Augunson Aarnes   M  23.0     NaN     NaN
# 96  33                 Mika Lauri Aarnikka   M  24.0   187.0    76.0
# 97  33                 Mika Lauri Aarnikka   M  28.0   187.0    76.0
# 98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0    76.0
# 99  35              Dagfinn Sverre Aarskog   M  24.0   190.0    98.0
#
#               Team  NOC        Games  Year
# 0            China  CHN  1992 Summer  1992
# 1            China  CHN  2012 Summer  2012
# ...

# %%
data.drop(['NOC','Team','Games'], axis=1)
# Out:
#     ID                                Name Sex   Age  Height  Weight  Year
# 0    1                           A Dijiang   M  24.0   180.0    80.0  1992
# 1    2                            A Lamusi   M  23.0   170.0    60.0  2012
# 4    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0  1988
# 5    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0  1988
# 6    5            Christine Jacoba Aaftink   F  25.0   185.0    82.0  1992
# ..  ..                                 ...  ..   ...     ...     ...   ...
# 94  31                   Evald rma (rman-)   M  24.0   174.0    70.0  1936
# 96  33                 Mika Lauri Aarnikka   M  24.0   187.0    76.0  1992
# 97  33                 Mika Lauri Aarnikka   M  28.0   187.0    76.0  1996
# 98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0    76.0  2012
# 99  35              Dagfinn Sverre Aarskog   M  24.0   190.0    98.0  1998
#
# [81 rows x 7 columns]

# %% [markdown]
# # Removing duplicates and null values

# %%
data.isnull()
# Out:
#        ID   Name    Sex    Age  Height  Weight   Team    NOC  Games   Year
# 0   False  False  False  False   False   False  False  False  False  False
# 1   False  False  False  False   False   False  False  False  False  False
# 2   False  False  False  False    True    True  False  False  False  False
# 3   False  False  False  False    True    True  False  False  False  False
# 4   False  False  False  False   False   False  False  False  False  False
# ..    ...    ...    ...    ...     ...     ...    ...    ...    ...    ...
# 95  False  False  False  False    True    True  False  False  False  False
# 96  False  False  False  False   False   False  False  False  False  False
# 97  False  False  False  False   False   False  False  False  False  False
# 98  False  False  False  False   False   False  False  False  False  False
# 99  False  False  False  False   False   False  False  False  False  False
#
# [100 rows x 10 columns]

# %%
data = data.dropna()

# %%
data
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 4    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6    5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# ..  ..                                 ...  ..   ...     ...     ...
# 94  31                   Evald rma (rman-)   M  24.0   174.0    70.0
# 96  33                 Mika Lauri Aarnikka   M  24.0   187.0    76.0
# 97  33                 Mika Lauri Aarnikka   M  28.0   187.0    76.0
# 98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0    76.0
# 99  35              Dagfinn Sverre Aarskog   M  24.0   190.0    98.0
#
#            Team  NOC        Games  Year
# 0         China  CHN  1992 Summer  1992
# 1         China  CHN  2012 Summer  2012
# ...

# %%
data=data.drop(['NOC','Team','Games'], axis=1)

# %%
data
# Out:
#     ID                                Name Sex   Age  Height  Weight  Year
# 0    1                           A Dijiang   M  24.0   180.0    80.0  1992
# 1    2                            A Lamusi   M  23.0   170.0    60.0  2012
# 4    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0  1988
# 5    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0  1988
# 6    5            Christine Jacoba Aaftink   F  25.0   185.0    82.0  1992
# ..  ..                                 ...  ..   ...     ...     ...   ...
# 94  31                   Evald rma (rman-)   M  24.0   174.0    70.0  1936
# 96  33                 Mika Lauri Aarnikka   M  24.0   187.0    76.0  1992
# 97  33                 Mika Lauri Aarnikka   M  28.0   187.0    76.0  1996
# 98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0    76.0  2012
# 99  35              Dagfinn Sverre Aarskog   M  24.0   190.0    98.0  1998
#
# [81 rows x 7 columns]

# %%
data.drop_duplicates()
# Out:
#     ID                                Name Sex   Age  Height  Weight  Year
# 0    1                           A Dijiang   M  24.0   180.0    80.0  1992
# 1    2                            A Lamusi   M  23.0   170.0    60.0  2012
# 4    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0  1988
# 6    5            Christine Jacoba Aaftink   F  25.0   185.0    82.0  1992
# 8    5            Christine Jacoba Aaftink   F  27.0   185.0    82.0  1994
# 10   6                     Per Knut Aaland   M  31.0   188.0    75.0  1992
# 14   6                     Per Knut Aaland   M  33.0   188.0    75.0  1994
# 18   7                        John Aalberg   M  31.0   183.0    72.0  1992
# 22   7                        John Aalberg   M  33.0   183.0    72.0  1994
# 28   9                    Antti Sami Aalto   M  26.0   186.0    96.0  2002
# 30  11                  Jorma Ilmari Aalto   M  22.0   182.0    76.5  1980
# ...

# %%
data = data.reset_index()

# %%
data
# Out:
#     index  ID                                Name Sex   Age  Height  Weight  \
# 0       0   1                           A Dijiang   M  24.0   180.0    80.0
# 1       1   2                            A Lamusi   M  23.0   170.0    60.0
# 2       4   5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 3       5   5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 4       6   5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# ..    ...  ..                                 ...  ..   ...     ...     ...
# 76     94  31                   Evald rma (rman-)   M  24.0   174.0    70.0
# 77     96  33                 Mika Lauri Aarnikka   M  24.0   187.0    76.0
# 78     97  33                 Mika Lauri Aarnikka   M  28.0   187.0    76.0
# 79     98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0    76.0
# 80     99  35              Dagfinn Sverre Aarskog   M  24.0   190.0    98.0
#
#     Year
# 0   1992
# 1   2012
# 2   1988
# 3   1988
# ...
